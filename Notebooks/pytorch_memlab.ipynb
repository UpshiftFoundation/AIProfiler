# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Pytorch_memlab
# **A library for memory profiling. Uses torch.cuda.memory_stats() inside.**

# %%
#!pip install git+https://github.com/stonesjtu/pytorch_memlab

# %%
# !pip install torch transformers pytorch_memlab
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (2.0.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.27.2)
# Requirement already satisfied: pytorch_memlab in /usr/local/lib/python3.9/dist-packages (0.2.4)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.9/dist-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.9/dist-packages (from torch) (11.7.101)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.9/dist-packages (from torch) (10.9.0.58)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.9/dist-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.9/dist-packages (from torch) (11.7.91)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.9/dist-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.9/dist-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.9/dist-packages (from torch) (2.14.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch) (3.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.9/dist-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.9/dist-packages (from torch) (11.4.0.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.9/dist-packages (from torch) (10.2.10.91)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch) (3.10.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.40.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (67.6.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch) (16.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: calmsize in /usr/local/lib/python3.9/dist-packages (from pytorch_memlab) (0.1.3)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.9/dist-packages (from pytorch_memlab) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.18->pytorch_memlab) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.18->pytorch_memlab) (2022.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=0.18->pytorch_memlab) (1.16.0)

# %% [markdown]
# # **Memory Profiler**

# %% [markdown]
# The memory profiler is a modification of python's line_profiler, it gives the memory usage info for each line of code in the specified function/method.

# %%
import torch
from pytorch_memlab import LineProfiler

def inner():
    torch.nn.Linear(100, 100).cuda()

def outer():
    linear = torch.nn.Linear(100, 100).cuda()
    linear2 = torch.nn.Linear(100, 100).cuda()
    inner()

with LineProfiler(outer, inner) as prof:
    outer()
prof.display()
# Out:
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_profiler.py", line 81, in register_callback
#     sys.settrace(self._trace_callback)
#
#
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_profiler.py", line 100, in disable
#     sys.settrace(None)
#
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:60: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   records = (_accumulate_line_records(raw_line_records)
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:189: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   merged = merged.drop('code', 1, level=0)
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:189: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   merged = merged.drop('code', 1, level=0)
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   html[qual_name] = (style
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html[qual_name] = (style
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   html[qual_name] = (style
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html[qual_name] = (style
# ## outer
#
# active_bytes reserved_bytes line code
#          all            all
#         peak           peak
#        0.00B          0.00B    7 def outer():
#       40.00K          2.00M    8     linear = torch.nn.Linear(100, 100).cuda()
#       80.00K          2.00M    9     linear2 = torch.nn.Linear(100, 100).cuda()
#      120.00K          2.00M   10     inner()
#
#
# ## inner
#
# active_bytes reserved_bytes line code
#          all            all
#         peak           peak
#       80.00K          2.00M    4 def inner():
#      120.00K          2.00M    5     torch.nn.Linear(100, 100).cuda()

# %% [markdown]
# # **Memory Reporter**

# %% [markdown]
# As Memory Profiler only gives the overall memory usage information by lines, a more low-level memory usage information can be obtained by Memory Reporter.
#
# Memory reporter iterates all the Tensor objects and gets the underlying Storage object to get the actual memory usage instead of the surface Tensor.size.

# %%
import torch
from pytorch_memlab import MemReporter
linear = torch.nn.Linear(1024, 1024).cuda()
reporter = MemReporter()

# %%
reporter.print_stats()
# Out:
# Element type                                            Size  Used MEM

# %%
reporter.report()
# Out:
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# Parameter0                                      (1024, 1024)     4.00M
# Parameter1                                           (1024,)     4.00K
# -------------------------------------------------------------------------------
# Total Tensors: 1049600 	Used Memory: 4.00M
# The allocated memory on cuda:0: 4.00M
# -------------------------------------------------------------------------------
# /usr/local/lib/python3.9/dist-packages/torch/distributed/distributed_c10d.py:283: UserWarning: torch.distributed.reduce_op is deprecated, please use torch.distributed.ReduceOp instead
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/mem_reporter.py:95: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   fact_numel = tensor.storage().size()
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/mem_reporter.py:104: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   data_ptr = tensor.storage().data_ptr()

# %%
import torch
from pytorch_memlab import MemReporter

linear = torch.nn.Linear(1024, 1024).cuda()
inp = torch.Tensor(512, 1024).cuda()
# pass in a model to automatically infer the tensor names
reporter = MemReporter(linear)
out = linear(inp).mean()
print('========= before backward =========')
reporter.report()
out.backward()
print('========= after backward =========')
reporter.report()
# Out:
# ========= before backward =========
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# weight                                          (1024, 1024)     4.00M
# bias                                                 (1024,)     4.00K
# Tensor0                                          (512, 1024)     2.00M
# Tensor1                                          (512, 1024)     2.00M
# Tensor2                                                 (1,)   512.00B
# -------------------------------------------------------------------------------
# Total Tensors: 2098177 	Used Memory: 8.00M
# The allocated memory on cuda:0: 16.13M
# Memory differs due to the matrix alignment or invisible gradient buffer tensors
# -------------------------------------------------------------------------------
# ========= after backward =========
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# weight                                          (1024, 1024)     4.00M
# weight.grad                                     (1024, 1024)     4.00M
# bias                                                 (1024,)     4.00K
# bias.grad                                            (1024,)     4.00K
# Tensor0                                          (512, 1024)     2.00M
# Tensor2                                                 (1,)   512.00B
# -------------------------------------------------------------------------------
# Total Tensors: 2623489 	Used Memory: 10.01M
# The allocated memory on cuda:0: 26.26M
# Memory differs due to the matrix alignment or invisible gradient buffer tensors
# -------------------------------------------------------------------------------

# %%
import torch
from pytorch_memlab import MemReporter

linear = torch.nn.Linear(1024, 1024).cuda()
linear2 = torch.nn.Linear(1024, 1024).cuda()
linear2.weight = linear.weight
container = torch.nn.Sequential(
    linear, linear2
)
inp = torch.Tensor(512, 1024).cuda()
# pass in a model to automatically infer the tensor names

out = container(inp).mean()
out.backward()

# verbose shows how storage is shared across multiple Tensors
reporter = MemReporter(container)
reporter.report(verbose=True)
# Out:
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# Parameter0                                      (1024, 1024)     4.00M
# Parameter0.grad                                 (1024, 1024)     4.00M
# Parameter1                                           (1024,)     4.00K
# Parameter1.grad                                      (1024,)     4.00K
# Tensor2                                          (512, 1024)     2.00M
# Tensor3                                                 (1,)   512.00B
# Parameter0.grad(->Parameter0.grad)              (1024, 1024)     0.00B
# Parameter1.grad(->Parameter1.grad)                   (1024,)     0.00B
# 0.weight                                        (1024, 1024)     4.00M
# 0.weight.grad                                   (1024, 1024)     4.00M
# 0.bias                                               (1024,)     4.00K
# 0.bias.grad                                          (1024,)     4.00K
# 1.bias                                               (1024,)     4.00K
# 1.bias.grad                                          (1024,)     4.00K
# Tensor4                                          (512, 1024)     2.00M
# Tensor5                                                 (1,)   512.00B
# -------------------------------------------------------------------------------
# Total Tensors: 6298626 	Used Memory: 20.02M
# The allocated memory on cuda:0: 36.27M
# Memory differs due to the matrix alignment or invisible gradient buffer tensors
# -------------------------------------------------------------------------------

# %%
import torch
from pytorch_memlab import MemReporter

lstm = torch.nn.LSTM(1024, 1024).cuda()
reporter = MemReporter(lstm)
reporter.report(verbose=True)
inp = torch.Tensor(10, 10, 1024).cuda()
out, _ = lstm(inp)
out.mean().backward()
reporter.report(verbose=True)
# Out:
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# Parameter0                                      (1024, 1024)     4.00M
# Parameter0.grad                                 (1024, 1024)     4.00M
# Parameter1                                           (1024,)     4.00K
# Parameter1.grad                                      (1024,)     4.00K
# Parameter2                                           (1024,)     4.00K
# Parameter2.grad                                      (1024,)     4.00K
# Tensor3                                          (512, 1024)     2.00M
# Tensor4                                                 (1,)   512.00B
# Parameter0.grad(->Parameter0.grad)              (1024, 1024)     0.00B
# Parameter1.grad(->Parameter1.grad)                   (1024,)     0.00B
# Parameter2.grad(->Parameter2.grad)                   (1024,)     0.00B
# weight_ih_l0                                    (4096, 1024)    32.03M
# weight_hh_l0(->weight_ih_l0)                    (4096, 1024)     0.00B
# bias_ih_l0(->weight_ih_l0)                           (4096,)     0.00B
# bias_hh_l0(->weight_ih_l0)                           (4096,)     0.00B
# -------------------------------------------------------------------------------
# Total Tensors: 12072961 	Used Memory: 42.05M
# The allocated memory on cuda:0: 58.30M
# Memory differs due to the matrix alignment or invisible gradient buffer tensors
# -------------------------------------------------------------------------------
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# Parameter0                                      (1024, 1024)     4.00M
# Parameter0.grad                                 (1024, 1024)     4.00M
# Parameter1                                           (1024,)     4.00K
# Parameter1.grad                                      (1024,)     4.00K
# Parameter2                                           (1024,)     4.00K
# Parameter2.grad                                      (1024,)     4.00K
# Parameter0.grad(->Parameter0.grad)              (1024, 1024)     0.00B
# Parameter1.grad(->Parameter1.grad)                   (1024,)     0.00B
# Parameter2.grad(->Parameter2.grad)                   (1024,)     0.00B
# weight_ih_l0                                    (4096, 1024)    32.03M
# weight_ih_l0.grad                               (4096, 1024)    32.03M
# weight_hh_l0(->weight_ih_l0)                    (4096, 1024)     0.00B
# weight_hh_l0.grad(->weight_ih_l0.grad)          (4096, 1024)     0.00B
# bias_ih_l0(->weight_ih_l0)                           (4096,)     0.00B
# bias_ih_l0.grad(->weight_ih_l0.grad)                 (4096,)     0.00B
# bias_hh_l0(->weight_ih_l0)                           (4096,)     0.00B
# bias_hh_l0.grad(->weight_ih_l0.grad)                 (4096,)     0.00B
# Tensor5                                       (10, 10, 1024)   400.00K
# Tensor6                                       (10, 10, 1024)   400.00K
# Tensor3                                        (1, 10, 1024)    40.00K
# Tensor7                                        (1, 10, 1024)    40.00K
# -------------------------------------------------------------------------------
# Total Tensors: 20170752 	Used Memory: 72.94M
# The allocated memory on cuda:0: 89.19M
# Memory differs due to the matrix alignment or invisible gradient buffer tensors
# -------------------------------------------------------------------------------

# %%
import torch
from pytorch_memlab import MemReporter

linear = torch.nn.Linear(1024, 1024).cuda()
inp = torch.Tensor(512, 1024).cuda()
# pass in a model to automatically infer the tensor names
reporter = MemReporter(linear)
out = linear(inp * (inp + 2)).mean()
reporter.report()
# Out:
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# weight                                          (1024, 1024)     4.00M
# bias                                                 (1024,)     4.00K
# Tensor0                                          (512, 1024)     2.00M
# Tensor1                                          (512, 1024)     2.00M
# Tensor2                                          (512, 1024)     2.00M
# Tensor3                                                 (1,)   512.00B
# Tensor4                                         (1024, 1024)     4.00M
# Tensor5                                              (1024,)     4.00K
# Tensor6                                              (1024,)     4.00K
# Tensor7                                       (10, 10, 1024)   400.00K
# Tensor8                                       (10, 10, 1024)   400.00K
# Tensor9                                         (4096, 1024)    32.03M
# Tensor10                                        (4096, 1024)     0.00B
# Tensor11                                             (4096,)     0.00B
# Tensor12                                             (4096,)     0.00B
# Parameter13                                          (4096,)    32.03M
# Parameter13.grad                                     (4096,)     0.00B
# Parameter14                                          (4096,)     0.00B
# Parameter14.grad                                     (4096,)     0.00B
# Parameter15                                     (4096, 1024)     0.00B
# Parameter15.grad                                (4096, 1024)     0.00B
# Parameter16                                     (4096, 1024)     0.00B
# Parameter16.grad                                (4096, 1024)     0.00B
# Tensor17                                       (1, 10, 1024)    40.00K
# Tensor18                                       (1, 10, 1024)    40.00K
# Parameter19                                     (1024, 1024)     4.00M
# Parameter19.grad                                (1024, 1024)     0.00B
# Parameter20                                          (1024,)     4.00K
# Parameter20.grad                                     (1024,)     0.00B
# Parameter21                                          (1024,)     4.00K
# Parameter21.grad                                     (1024,)     0.00B
# -------------------------------------------------------------------------------
# Total Tensors: 31190017 	Used Memory: 82.94M
# The allocated memory on cuda:0: 99.19M
# Memory differs due to the matrix alignment or invisible gradient buffer tensors
# -------------------------------------------------------------------------------

# %% [markdown]
# # **Courtesy**

# %% [markdown]
# Sometimes people would like to preempt your running task, but you don't want to save checkpoint and then load, actually all they need is GPU resources ( typically CPU resources and CPU memory is always spare in GPU clusters), so you can move all your workspaces from GPU to CPU and then halt your task until a restart signal is triggered, instead of saving&loading checkpoints and bootstrapping from scratch.

# %%
from pytorch_memlab import Courtesy

iamcourtesy = Courtesy()
#for i in range(num_iteration):
#    if something_happens:
#        iamcourtesy.yield_memory()
#        wait_for_restart_signal()
#        iamcourtesy.restore()

# %%
iamcourtesy

# %% [markdown]
# # **Demo**

# %%
import torch
from pytorch_memlab import LineProfiler, MemReporter, profile
from transformers import BertForTokenClassification, BertTokenizerFast

# %%
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

# %%
model = BertForTokenClassification.from_pretrained(
                'bert-base-cased',
                num_labels=10
).cuda()
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForTokenClassification: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
tokenizer = BertTokenizerFast.from_pretrained('bert-base-cased')

# %% [markdown]
# # **GPT-3**

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("minhtoan/gpt3-small-finetune-cnndaily-news")

model = AutoModelForCausalLM.from_pretrained("minhtoan/gpt3-small-finetune-cnndaily-news").cuda()

# %%
model
# Out:
# GPTNeoForCausalLM(
#   (transformer): GPTNeoModel(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(2048, 768)
#     (drop): Dropout(p=0.0, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPTNeoBlock(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTNeoAttention(
#           (attention): GPTNeoSelfAttention(
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#             (k_proj): Linear(in_features=768, out_features=768, bias=False)
#             (v_proj): Linear(in_features=768, out_features=768, bias=False)
#             (q_proj): Linear(in_features=768, out_features=768, bias=False)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPTNeoMLP(
#           (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#           (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %% [markdown]
# # Memory Reporter

# %% [markdown]
# We can inspect the memory used by the model tensors.

# %%
reporter = MemReporter(model)

# %%
#BERT
reporter.report(device=device, verbose=True)
# Out:
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# Tensor0                                         (1024, 1024)     4.00M
# Tensor1                                              (1024,)     4.00K
# Tensor2                                              (1024,)     4.00K
# Tensor3                                         (4096, 1024)    32.03M
# Tensor4(->Tensor3)                              (4096, 1024)     0.00B
# Tensor5(->Tensor3)                                   (4096,)     0.00B
# Tensor6(->Tensor3)                                   (4096,)     0.00B
# Parameter7                                           (4096,)    32.03M
# Parameter7.grad(->Tensor3)                           (4096,)     0.00B
# Parameter8(->Parameter7)                             (4096,)     0.00B
# Parameter8.grad(->Tensor3)                           (4096,)     0.00B
# Parameter9(->Parameter7)                        (4096, 1024)     0.00B
# Parameter9.grad(->Tensor3)                      (4096, 1024)     0.00B
# Parameter10(->Parameter7)                       (4096, 1024)     0.00B
# Parameter10.grad(->Tensor3)                     (4096, 1024)     0.00B
# Tensor11                                       (1, 10, 1024)    40.00K
# Tensor12                                       (1, 10, 1024)    40.00K
# Parameter13                                     (1024, 1024)     4.00M
# Parameter13.grad(->Tensor0)                     (1024, 1024)     0.00B
# Parameter14                                          (1024,)     4.00K
# Parameter14.grad(->Tensor2)                          (1024,)     0.00B
# Tensor15                                         (512, 1024)     2.00M
# Tensor16                                         (512, 1024)     2.00M
# Tensor17                                         (512, 1024)     2.00M
# Tensor18                                                (1,)   512.00B
# Parameter19                                     (1024, 1024)     4.00M
# Parameter20                                          (1024,)     4.00K
# Parameter21                                          (1024,)     4.00K
# Parameter21.grad(->Tensor1)                          (1024,)     0.00B
# bert.embeddings.word_embeddings.weight          (28996, 768)    84.95M
# bert.embeddings.position_embeddings.weight          (512, 768)     1.50M
# bert.embeddings.token_type_embeddings.weight            (2, 768)     6.00K
# bert.embeddings.LayerNorm.weight                      (768,)     3.00K
# bert.embeddings.LayerNorm.bias                        (768,)     3.00K
# classifier.weight                                  (10, 768)    30.00K
# classifier.bias                                        (10,)   512.00B
# bert.encoder.layer.11.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.11.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.11.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.11.output.dense.bias               (768,)     3.00K
# bert.encoder.layer.11.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.11.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.11.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.11.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.11.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.11.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.11.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.11.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.11.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.11.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.11.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.11.attention.output.LayerNorm.bias              (768,)     3.00K
# Tensor22                                            (1, 512)     4.00K
# Tensor23                                            (1, 512)     4.00K
# bert.encoder.layer.0.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.0.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.0.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.0.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.0.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.0.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.1.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.1.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.1.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.1.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.1.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.1.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.2.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.2.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.2.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.2.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.2.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.2.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.3.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.3.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.3.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.3.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.3.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.3.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.4.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.4.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.4.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.4.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.4.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.4.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.5.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.5.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.5.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.5.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.5.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.5.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.6.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.6.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.6.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.6.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.6.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.6.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.7.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.7.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.7.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.7.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.7.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.7.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.8.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.8.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.8.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.8.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.8.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.8.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.9.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.9.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.9.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.9.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.9.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.9.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.10.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.10.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.10.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.10.output.dense.bias               (768,)     3.00K
# bert.encoder.layer.10.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.10.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.0.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.0.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.0.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.0.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.0.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.0.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.0.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.0.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.0.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.0.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.1.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.1.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.1.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.1.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.1.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.1.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.1.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.1.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.1.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.1.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.2.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.2.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.2.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.2.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.2.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.2.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.2.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.2.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.2.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.2.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.3.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.3.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.3.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.3.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.3.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.3.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.3.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.3.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.3.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.3.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.4.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.4.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.4.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.4.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.4.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.4.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.4.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.4.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.4.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.4.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.5.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.5.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.5.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.5.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.5.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.5.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.5.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.5.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.5.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.5.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.6.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.6.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.6.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.6.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.6.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.6.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.6.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.6.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.6.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.6.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.7.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.7.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.7.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.7.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.7.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.7.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.7.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.7.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.7.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.7.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.8.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.8.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.8.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.8.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.8.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.8.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.8.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.8.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.8.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.8.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.9.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.9.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.9.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.9.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.9.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.9.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.9.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.9.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.9.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.9.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.10.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.10.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.10.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.10.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.10.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.10.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.10.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.10.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.10.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.10.attention.output.LayerNorm.bias              (768,)     3.00K
# -------------------------------------------------------------------------------
# Total Tensors: 138713611 	Used Memory: 493.12M
# The allocated memory on cuda:0: 510.87M
# Memory differs due to the matrix alignment or invisible gradient buffer tensors
# -------------------------------------------------------------------------------
# /usr/local/lib/python3.9/dist-packages/torch/distributed/distributed_c10d.py:283: UserWarning: torch.distributed.reduce_op is deprecated, please use torch.distributed.ReduceOp instead
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/mem_reporter.py:95: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   fact_numel = tensor.storage().size()
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/mem_reporter.py:104: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   data_ptr = tensor.storage().data_ptr()

# %%
#GPT3
reporter.report(device=device, verbose = True)
# Out:
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# Tensor0                                   (1, 1, 2048, 2048)     4.00M
# Tensor1                                                 (1,)   512.00B
# Tensor2                                   (1, 1, 2048, 2048)     4.00M
# Tensor3                                                 (1,)   512.00B
# Tensor4                                   (1, 1, 2048, 2048)     4.00M
# Tensor5                                                 (1,)   512.00B
# Tensor6                                   (1, 1, 2048, 2048)     4.00M
# Tensor7                                                 (1,)   512.00B
# Tensor8                                   (1, 1, 2048, 2048)     4.00M
# Tensor9                                                 (1,)   512.00B
# Tensor10                                  (1, 1, 2048, 2048)     4.00M
# Tensor11                                                (1,)   512.00B
# Tensor12                                  (1, 1, 2048, 2048)     4.00M
# Tensor13                                                (1,)   512.00B
# Tensor14                                  (1, 1, 2048, 2048)     4.00M
# Tensor15                                                (1,)   512.00B
# Tensor16                                  (1, 1, 2048, 2048)     4.00M
# Tensor17                                                (1,)   512.00B
# Tensor18                                  (1, 1, 2048, 2048)     4.00M
# Tensor19                                                (1,)   512.00B
# Tensor20                                  (1, 1, 2048, 2048)     4.00M
# Tensor21                                                (1,)   512.00B
# Tensor22                                  (1, 1, 2048, 2048)     4.00M
# Tensor23                                                (1,)   512.00B
# transformer.h.1.ln_2.weight                           (768,)     3.00K
# transformer.h.1.ln_2.bias                             (768,)     3.00K
# transformer.h.1.mlp.c_fc.weight                  (3072, 768)     9.00M
# transformer.h.1.mlp.c_fc.bias                        (3072,)    12.00K
# transformer.h.1.mlp.c_proj.weight                (768, 3072)     9.00M
# transformer.h.1.mlp.c_proj.bias                       (768,)     3.00K
# transformer.h.2.ln_1.weight                           (768,)     3.00K
# transformer.h.2.ln_1.bias                             (768,)     3.00K
# transformer.h.2.attn.attention.k_proj.weight          (768, 768)     2.25M
# transformer.h.2.attn.attention.v_proj.weight          (768, 768)     2.25M
# transformer.h.2.attn.attention.q_proj.weight          (768, 768)     2.25M
# transformer.h.2.attn.attention.out_proj.weight          (768, 768)     2.25M
# transformer.h.2.attn.attention.out_proj.bias              (768,)     3.00K
# transformer.h.2.ln_2.weight                           (768,)     3.00K
# transformer.h.2.ln_2.bias                             (768,)     3.00K
# transformer.h.2.mlp.c_fc.weight                  (3072, 768)     9.00M
# transformer.h.2.mlp.c_fc.bias                        (3072,)    12.00K
# transformer.h.2.mlp.c_proj.weight                (768, 3072)     9.00M
# transformer.h.2.mlp.c_proj.bias                       (768,)     3.00K
# transformer.h.3.ln_1.weight                           (768,)     3.00K
# transformer.h.3.ln_1.bias                             (768,)     3.00K
# transformer.h.3.attn.attention.k_proj.weight          (768, 768)     2.25M
# transformer.h.3.attn.attention.v_proj.weight          (768, 768)     2.25M
# transformer.h.3.attn.attention.q_proj.weight          (768, 768)     2.25M
# transformer.h.3.attn.attention.out_proj.weight          (768, 768)     2.25M
# transformer.h.3.attn.attention.out_proj.bias              (768,)     3.00K
# transformer.h.3.ln_2.weight                           (768,)     3.00K
# transformer.h.3.ln_2.bias                             (768,)     3.00K
# transformer.h.3.mlp.c_fc.weight                  (3072, 768)     9.00M
# transformer.h.3.mlp.c_fc.bias                        (3072,)    12.00K
# transformer.h.3.mlp.c_proj.weight                (768, 3072)     9.00M
# transformer.h.3.mlp.c_proj.bias                       (768,)     3.00K
# transformer.h.4.ln_1.weight                           (768,)     3.00K
# transformer.h.4.ln_1.bias                             (768,)     3.00K
# transformer.h.4.attn.attention.k_proj.weight          (768, 768)     2.25M
# transformer.h.4.attn.attention.v_proj.weight          (768, 768)     2.25M
# transformer.h.4.attn.attention.q_proj.weight          (768, 768)     2.25M
# transformer.h.4.attn.attention.out_proj.weight          (768, 768)     2.25M
# transformer.h.4.attn.attention.out_proj.bias              (768,)     3.00K
# transformer.h.4.ln_2.weight                           (768,)     3.00K
# transformer.h.4.ln_2.bias                             (768,)     3.00K
# transformer.h.4.mlp.c_fc.weight                  (3072, 768)     9.00M
# transformer.h.4.mlp.c_fc.bias                        (3072,)    12.00K
# transformer.h.4.mlp.c_proj.weight                (768, 3072)     9.00M
# transformer.h.4.mlp.c_proj.bias                       (768,)     3.00K
# transformer.h.5.ln_1.weight                           (768,)     3.00K
# transformer.h.5.ln_1.bias                             (768,)     3.00K
# transformer.h.5.attn.attention.k_proj.weight          (768, 768)     2.25M
# transformer.h.5.attn.attention.v_proj.weight          (768, 768)     2.25M
# transformer.h.5.attn.attention.q_proj.weight          (768, 768)     2.25M
# transformer.h.5.attn.attention.out_proj.weight          (768, 768)     2.25M
# transformer.h.5.attn.attention.out_proj.bias              (768,)     3.00K
# transformer.h.5.ln_2.weight                           (768,)     3.00K
# transformer.h.5.ln_2.bias                             (768,)     3.00K
# transformer.h.5.mlp.c_fc.weight                  (3072, 768)     9.00M
# transformer.h.5.mlp.c_fc.bias                        (3072,)    12.00K
# transformer.h.5.mlp.c_proj.weight                (768, 3072)     9.00M
# transformer.h.5.mlp.c_proj.bias                       (768,)     3.00K
# transformer.h.6.ln_1.weight                           (768,)     3.00K
# transformer.h.6.ln_1.bias                             (768,)     3.00K
# transformer.h.6.attn.attention.k_proj.weight          (768, 768)     2.25M
# transformer.h.6.attn.attention.v_proj.weight          (768, 768)     2.25M
# transformer.h.6.attn.attention.q_proj.weight          (768, 768)     2.25M
# transformer.h.6.attn.attention.out_proj.weight          (768, 768)     2.25M
# transformer.h.6.attn.attention.out_proj.bias              (768,)     3.00K
# transformer.h.6.ln_2.weight                           (768,)     3.00K
# transformer.h.6.ln_2.bias                             (768,)     3.00K
# transformer.h.6.mlp.c_fc.weight                  (3072, 768)     9.00M
# transformer.h.6.mlp.c_fc.bias                        (3072,)    12.00K
# transformer.h.6.mlp.c_proj.weight                (768, 3072)     9.00M
# transformer.h.6.mlp.c_proj.bias                       (768,)     3.00K
# transformer.h.7.ln_1.weight                           (768,)     3.00K
# transformer.h.7.ln_1.bias                             (768,)     3.00K
# transformer.h.7.attn.attention.k_proj.weight          (768, 768)     2.25M
# transformer.h.7.attn.attention.v_proj.weight          (768, 768)     2.25M
# transformer.h.7.attn.attention.q_proj.weight          (768, 768)     2.25M
# transformer.h.7.attn.attention.out_proj.weight          (768, 768)     2.25M
# transformer.h.7.attn.attention.out_proj.bias              (768,)     3.00K
# transformer.h.7.ln_2.weight                           (768,)     3.00K
# transformer.h.7.ln_2.bias                             (768,)     3.00K
# transformer.h.7.mlp.c_fc.weight                  (3072, 768)     9.00M
# transformer.h.7.mlp.c_fc.bias                        (3072,)    12.00K
# transformer.h.7.mlp.c_proj.weight                (768, 3072)     9.00M
# transformer.h.7.mlp.c_proj.bias                       (768,)     3.00K
# transformer.h.8.ln_1.weight                           (768,)     3.00K
# transformer.h.8.ln_1.bias                             (768,)     3.00K
# transformer.h.8.attn.attention.k_proj.weight          (768, 768)     2.25M
# transformer.h.8.attn.attention.v_proj.weight          (768, 768)     2.25M
# transformer.h.8.attn.attention.q_proj.weight          (768, 768)     2.25M
# transformer.h.8.attn.attention.out_proj.weight          (768, 768)     2.25M
# transformer.h.8.attn.attention.out_proj.bias              (768,)     3.00K
# transformer.h.8.ln_2.weight                           (768,)     3.00K
# transformer.h.8.ln_2.bias                             (768,)     3.00K
# transformer.h.8.mlp.c_fc.weight                  (3072, 768)     9.00M
# transformer.h.8.mlp.c_fc.bias                        (3072,)    12.00K
# transformer.h.8.mlp.c_proj.weight                (768, 3072)     9.00M
# transformer.h.8.mlp.c_proj.bias                       (768,)     3.00K
# transformer.h.9.ln_1.weight                           (768,)     3.00K
# transformer.h.9.ln_1.bias                             (768,)     3.00K
# transformer.h.9.attn.attention.k_proj.weight          (768, 768)     2.25M
# transformer.h.9.attn.attention.v_proj.weight          (768, 768)     2.25M
# transformer.h.9.attn.attention.q_proj.weight          (768, 768)     2.25M
# transformer.h.9.attn.attention.out_proj.weight          (768, 768)     2.25M
# transformer.h.9.attn.attention.out_proj.bias              (768,)     3.00K
# transformer.h.9.ln_2.weight                           (768,)     3.00K
# transformer.h.9.ln_2.bias                             (768,)     3.00K
# transformer.h.9.mlp.c_fc.weight                  (3072, 768)     9.00M
# transformer.h.9.mlp.c_fc.bias                        (3072,)    12.00K
# transformer.h.9.mlp.c_proj.weight                (768, 3072)     9.00M
# transformer.h.9.mlp.c_proj.bias                       (768,)     3.00K
# transformer.h.10.ln_1.weight                          (768,)     3.00K
# transformer.h.10.ln_1.bias                            (768,)     3.00K
# transformer.h.10.attn.attention.k_proj.weight          (768, 768)     2.25M
# transformer.h.10.attn.attention.v_proj.weight          (768, 768)     2.25M
# transformer.h.10.attn.attention.q_proj.weight          (768, 768)     2.25M
# transformer.h.10.attn.attention.out_proj.weight          (768, 768)     2.25M
# transformer.h.10.attn.attention.out_proj.bias              (768,)     3.00K
# transformer.h.10.ln_2.weight                          (768,)     3.00K
# transformer.h.10.ln_2.bias                            (768,)     3.00K
# transformer.h.10.mlp.c_fc.weight                 (3072, 768)     9.00M
# transformer.h.10.mlp.c_fc.bias                       (3072,)    12.00K
# transformer.h.10.mlp.c_proj.weight               (768, 3072)     9.00M
# transformer.h.10.mlp.c_proj.bias                      (768,)     3.00K
# transformer.h.11.ln_1.weight                          (768,)     3.00K
# transformer.h.11.ln_1.bias                            (768,)     3.00K
# transformer.h.11.attn.attention.k_proj.weight          (768, 768)     2.25M
# transformer.h.11.attn.attention.v_proj.weight          (768, 768)     2.25M
# transformer.h.11.attn.attention.q_proj.weight          (768, 768)     2.25M
# transformer.h.11.attn.attention.out_proj.weight          (768, 768)     2.25M
# transformer.h.11.attn.attention.out_proj.bias              (768,)     3.00K
# transformer.h.11.ln_2.weight                          (768,)     3.00K
# transformer.h.11.ln_2.bias                            (768,)     3.00K
# transformer.h.11.mlp.c_fc.weight                 (3072, 768)     9.00M
# transformer.h.11.mlp.c_fc.bias                       (3072,)    12.00K
# transformer.h.11.mlp.c_proj.weight               (768, 3072)     9.00M
# transformer.h.11.mlp.c_proj.bias                      (768,)     3.00K
# transformer.ln_f.weight                               (768,)     3.00K
# transformer.ln_f.bias                                 (768,)     3.00K
# transformer.wte.weight                          (50257, 768)   147.24M
# transformer.wpe.weight                           (2048, 768)     6.00M
# transformer.h.0.ln_1.weight                           (768,)     3.00K
# transformer.h.0.ln_1.bias                             (768,)     3.00K
# transformer.h.0.attn.attention.k_proj.weight          (768, 768)     2.25M
# transformer.h.0.attn.attention.v_proj.weight          (768, 768)     2.25M
# transformer.h.0.attn.attention.q_proj.weight          (768, 768)     2.25M
# transformer.h.0.attn.attention.out_proj.weight          (768, 768)     2.25M
# transformer.h.0.attn.attention.out_proj.bias              (768,)     3.00K
# transformer.h.0.ln_2.weight                           (768,)     3.00K
# transformer.h.0.ln_2.bias                             (768,)     3.00K
# transformer.h.0.mlp.c_fc.weight                  (3072, 768)     9.00M
# transformer.h.0.mlp.c_fc.bias                        (3072,)    12.00K
# transformer.h.0.mlp.c_proj.weight                (768, 3072)     9.00M
# transformer.h.0.mlp.c_proj.bias                       (768,)     3.00K
# transformer.h.1.ln_1.weight                           (768,)     3.00K
# transformer.h.1.ln_1.bias                             (768,)     3.00K
# transformer.h.1.attn.attention.k_proj.weight          (768, 768)     2.25M
# transformer.h.1.attn.attention.v_proj.weight          (768, 768)     2.25M
# transformer.h.1.attn.attention.q_proj.weight          (768, 768)     2.25M
# transformer.h.1.attn.attention.out_proj.weight          (768, 768)     2.25M
# transformer.h.1.attn.attention.out_proj.bias              (768,)     3.00K
# -------------------------------------------------------------------------------
# Total Tensors: 175530252 	Used Memory: 525.60M
# The allocated memory on cuda:0: 529.86M
# Memory differs due to the matrix alignment or invisible gradient buffer tensors
# -------------------------------------------------------------------------------
# /usr/local/lib/python3.9/dist-packages/torch/distributed/distributed_c10d.py:283: UserWarning: torch.distributed.reduce_op is deprecated, please use torch.distributed.ReduceOp instead
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/mem_reporter.py:95: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   fact_numel = tensor.storage().size()
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/mem_reporter.py:104: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   data_ptr = tensor.storage().data_ptr()

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-xxl")

model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-xxl")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/674 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/50.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00005.bin:   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00005.bin:   0%|          | 0.00/9.60G [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00005.bin:   0%|          | 0.00/9.96G [00:00<?, ?B/s]
# Downloading (…)l-00004-of-00005.bin:   0%|          | 0.00/10.0G [00:00<?, ?B/s]
# Downloading (…)l-00005-of-00005.bin:   0%|          | 0.00/6.06G [00:00<?, ?B/s]

# %%
#FLAN T5
reporter = MemReporter(model)

reporter.report(device=device, verbose=True)

# %%
data = tokenizer(['This is a sentence'], return_tensors='pt').to(device)
labels = torch.Tensor([1] * len(data.input_ids[0])).to(dtype=torch.long).cuda()

# %%
loss, logits = model(data.input_ids, token_type_ids=None, attention_mask=data.attention_mask, labels=labels)
#loss.backward()

# %% [markdown]
# We calculated the gradients and they are now shown in memory inspection.

# %%
reporter = MemReporter(model)
reporter.report(device=device)
# Out:
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# Tensor0                                         (1024, 1024)     4.00M
# Tensor1                                              (1024,)     4.00K
# Tensor2                                              (1024,)     4.00K
# Tensor3                                         (4096, 1024)    32.03M
# Tensor4                                         (4096, 1024)     0.00B
# Tensor5                                              (4096,)     0.00B
# Tensor6                                              (4096,)     0.00B
# Parameter7                                           (4096,)    32.03M
# Parameter7.grad                                      (4096,)     0.00B
# Parameter8                                           (4096,)     0.00B
# Parameter8.grad                                      (4096,)     0.00B
# Parameter9                                      (4096, 1024)     0.00B
# Parameter9.grad                                 (4096, 1024)     0.00B
# Parameter10                                     (4096, 1024)     0.00B
# Parameter10.grad                                (4096, 1024)     0.00B
# Tensor11                                       (1, 10, 1024)    40.00K
# Tensor12                                       (1, 10, 1024)    40.00K
# Parameter13                                     (1024, 1024)     4.00M
# Parameter13.grad                                (1024, 1024)     0.00B
# Parameter14                                          (1024,)     4.00K
# Parameter14.grad                                     (1024,)     0.00B
# Tensor15                                         (512, 1024)     2.00M
# Tensor16                                         (512, 1024)     2.00M
# Tensor17                                         (512, 1024)     2.00M
# Tensor18                                                (1,)   512.00B
# Parameter19                                     (1024, 1024)     4.00M
# Parameter20                                          (1024,)     4.00K
# Parameter21                                          (1024,)     4.00K
# Parameter21.grad                                     (1024,)     0.00B
# bert.embeddings.word_embeddings.weight          (28996, 768)    84.95M
# bert.embeddings.position_embeddings.weight          (512, 768)     1.50M
# bert.embeddings.token_type_embeddings.weight            (2, 768)     6.00K
# bert.embeddings.LayerNorm.weight                      (768,)     3.00K
# bert.embeddings.LayerNorm.bias                        (768,)     3.00K
# classifier.weight                                  (10, 768)    30.00K
# classifier.bias                                        (10,)   512.00B
# bert.encoder.layer.11.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.11.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.11.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.11.output.dense.bias               (768,)     3.00K
# bert.encoder.layer.11.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.11.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.11.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.11.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.11.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.11.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.11.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.11.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.11.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.11.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.11.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.11.attention.output.LayerNorm.bias              (768,)     3.00K
# Tensor22                                            (1, 512)     4.00K
# Tensor23                                            (1, 512)     4.00K
# bert.encoder.layer.0.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.0.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.0.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.0.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.0.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.0.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.1.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.1.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.1.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.1.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.1.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.1.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.2.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.2.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.2.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.2.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.2.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.2.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.3.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.3.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.3.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.3.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.3.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.3.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.4.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.4.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.4.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.4.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.4.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.4.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.5.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.5.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.5.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.5.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.5.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.5.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.6.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.6.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.6.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.6.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.6.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.6.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.7.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.7.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.7.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.7.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.7.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.7.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.8.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.8.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.8.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.8.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.8.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.8.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.9.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.9.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.9.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.9.output.dense.bias                (768,)     3.00K
# bert.encoder.layer.9.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.9.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.10.intermediate.dense.weight         (3072, 768)     9.00M
# bert.encoder.layer.10.intermediate.dense.bias             (3072,)    12.00K
# bert.encoder.layer.10.output.dense.weight         (768, 3072)     9.00M
# bert.encoder.layer.10.output.dense.bias               (768,)     3.00K
# bert.encoder.layer.10.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.10.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.0.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.0.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.0.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.0.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.0.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.0.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.0.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.0.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.0.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.0.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.1.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.1.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.1.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.1.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.1.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.1.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.1.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.1.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.1.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.1.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.2.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.2.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.2.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.2.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.2.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.2.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.2.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.2.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.2.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.2.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.3.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.3.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.3.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.3.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.3.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.3.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.3.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.3.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.3.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.3.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.4.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.4.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.4.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.4.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.4.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.4.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.4.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.4.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.4.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.4.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.5.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.5.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.5.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.5.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.5.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.5.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.5.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.5.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.5.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.5.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.6.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.6.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.6.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.6.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.6.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.6.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.6.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.6.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.6.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.6.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.7.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.7.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.7.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.7.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.7.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.7.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.7.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.7.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.7.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.7.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.8.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.8.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.8.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.8.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.8.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.8.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.8.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.8.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.8.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.8.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.9.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.9.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.9.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.9.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.9.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.9.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.9.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.9.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.9.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.9.attention.output.LayerNorm.bias              (768,)     3.00K
# bert.encoder.layer.10.attention.self.query.weight          (768, 768)     2.25M
# bert.encoder.layer.10.attention.self.query.bias              (768,)     3.00K
# bert.encoder.layer.10.attention.self.key.weight          (768, 768)     2.25M
# bert.encoder.layer.10.attention.self.key.bias              (768,)     3.00K
# bert.encoder.layer.10.attention.self.value.weight          (768, 768)     2.25M
# bert.encoder.layer.10.attention.self.value.bias              (768,)     3.00K
# bert.encoder.layer.10.attention.output.dense.weight          (768, 768)     2.25M
# bert.encoder.layer.10.attention.output.dense.bias              (768,)     3.00K
# bert.encoder.layer.10.attention.output.LayerNorm.weight              (768,)     3.00K
# bert.encoder.layer.10.attention.output.LayerNorm.bias              (768,)     3.00K
# Tensor24                                              (1, 6)   512.00B
# Tensor25                                              (1, 6)   512.00B
# Tensor26                                                (6,)   512.00B
# Tensor27                                              (1, 6)   512.00B
# -------------------------------------------------------------------------------
# Total Tensors: 138713635 	Used Memory: 493.12M
# The allocated memory on cuda:0: 510.87M
# Memory differs due to the matrix alignment or invisible gradient buffer tensors
# -------------------------------------------------------------------------------

# %% [markdown]
# ## Shared parameters

# %% [markdown]
# We can also see that some variables are shared: reused memory is shown by '->'

# %%
# %reset -f

# %%
import torch
from pytorch_memlab import LineProfiler, MemReporter
device = torch.device('cuda:0')

# %%
# use verbose=True to see reused memory
lstm = torch.nn.LSTM(1024, 1024).cuda()
reporter = MemReporter(lstm)
reporter.report(device=device, verbose=True)
# Out:
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# weight_ih_l0                                    (4096, 1024)    32.03M
# weight_hh_l0(->weight_ih_l0)                    (4096, 1024)     0.00B
# bias_ih_l0(->weight_ih_l0)                           (4096,)     0.00B
# bias_hh_l0(->weight_ih_l0)                           (4096,)     0.00B
# -------------------------------------------------------------------------------
# Total Tensors: 8396800 	Used Memory: 32.03M
# The allocated memory on cuda:0: 48.28M
# Memory differs due to the matrix alignment or invisible gradient buffer tensors
# -------------------------------------------------------------------------------

# %% [markdown]
# ## Leaking memory

# %% [markdown]
# Sometimes used memory and allocated memory are not equal. This is due to memory leaks, the fact of which you can see but unfortunately not inspect. In the example below *input_tensor + 2* is a temporary operation result which is stored but not shown in memory inspection.

# %% [markdown]
# (Actually, if you try to run this notebook on torch==1.10.2 + transformers==4.17.0 + pytorch-memlab==0.2.4, memory leakage is gone - you'll see Tensor2 to account for a temporary result.)

# %%
# %reset -f

# %%
import torch
from pytorch_memlab import LineProfiler, MemReporter

linear = torch.nn.Linear(1024, 1024).cuda()
input_tensor = torch.Tensor(512, 1024).cuda()
reporter = MemReporter(linear)
reporter.report()

out = linear(input_tensor * (input_tensor + 2)).mean()
reporter.report()
# Out:
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# Parameter0                                      (4096, 1024)    32.03M
# Parameter1                                      (4096, 1024)     0.00B
# Parameter2                                           (4096,)     0.00B
# Parameter3                                           (4096,)     0.00B
# weight                                          (1024, 1024)     4.00M
# bias                                                 (1024,)     4.00K
# Tensor4                                          (512, 1024)     2.00M
# -------------------------------------------------------------------------------
# Total Tensors: 9970688 	Used Memory: 38.04M
# The allocated memory on cuda:0: 54.29M
# Memory differs due to the matrix alignment or invisible gradient buffer tensors
# -------------------------------------------------------------------------------
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cuda:0
# Parameter0                                      (4096, 1024)    32.03M
# Parameter1                                      (4096, 1024)     0.00B
# Parameter2                                           (4096,)     0.00B
# Parameter3                                           (4096,)     0.00B
# weight                                          (1024, 1024)     4.00M
# bias                                                 (1024,)     4.00K
# Tensor4                                          (512, 1024)     2.00M
# Tensor5                                          (512, 1024)     2.00M
# Tensor6                                          (512, 1024)     2.00M
# Tensor7                                                 (1,)   512.00B
# -------------------------------------------------------------------------------
# Total Tensors: 11019265 	Used Memory: 42.04M
# The allocated memory on cuda:0: 58.29M
# Memory differs due to the matrix alignment or invisible gradient buffer tensors
# -------------------------------------------------------------------------------

# %% [markdown]
# # Line Profiler

# %% [markdown]
# Line profiler can show memory usage line by line.

# %%
# %reset -f

# %%
import torch
from pytorch_memlab import LineProfiler, MemReporter, profile
from transformers import BertForTokenClassification, BertTokenizerFast, BertModel

# %% [markdown]
# ### A simple case

# %%
def inner():
    torch.nn.Linear(100, 100).cuda()

def outer():
    linear = torch.nn.Linear(100, 100).cuda()
    linear2 = torch.nn.Linear(100, 100).cuda()
    inner()

with LineProfiler(outer, inner) as prof:
    outer()
prof.display()
# Out:
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:60: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   records = (_accumulate_line_records(raw_line_records)
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:189: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   merged = merged.drop('code', 1, level=0)
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:189: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   merged = merged.drop('code', 1, level=0)
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   html[qual_name] = (style
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html[qual_name] = (style
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   html[qual_name] = (style
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html[qual_name] = (style
# ## outer
#
# active_bytes reserved_bytes line code
#          all            all
#         peak           peak
#       58.29M         72.00M    4 def outer():
#       58.32M         72.00M    5     linear = torch.nn.Linear(100, 100).cuda()
#       58.36M         72.00M    6     linear2 = torch.nn.Linear(100, 100).cuda()
#       58.40M         72.00M    7     inner()
#
#
# ## inner
#
# active_bytes reserved_bytes line code
#          all            all
#         peak           peak
#       58.36M         72.00M    1 def inner():
#       58.40M         72.00M    2     torch.nn.Linear(100, 100).cuda()

# %% [markdown]
# ### Trying to profile BERT

# %%
def initialize_model():
    model = BertForTokenClassification.from_pretrained('bert-base-cased', num_labels=10).cuda()
    return model

# %%
def get_data():
    device = torch.device('cuda:0')
    tokenizer = BertTokenizerFast.from_pretrained('bert-base-cased')
    data = tokenizer(['This is a sentence'], return_tensors='pt').to(device)
    labels = torch.Tensor([1] * len(data.input_ids[0])).to(dtype=torch.long).cuda()
    return data, labels

# %%
def run_model():
    model = initialize_model()
    data, labels = get_data()
    loss, logits = model(data.input_ids, token_type_ids=None, attention_mask=data.attention_mask, labels=labels)
    return loss

# %%
with LineProfiler(run_model, initialize_model, get_data) as prof:
    run_model()
prof.display()
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForTokenClassification: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:60: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   records = (_accumulate_line_records(raw_line_records)
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:189: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   merged = merged.drop('code', 1, level=0)
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:189: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   merged = merged.drop('code', 1, level=0)
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:189: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   merged = merged.drop('code', 1, level=0)
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   html[qual_name] = (style
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html[qual_name] = (style
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   html[qual_name] = (style
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html[qual_name] = (style
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   html[qual_name] = (style
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:215: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html[qual_name] = (style
# ## run_model
#
# active_bytes reserved_bytes line code
#          all            all
#         peak           peak
#       58.29M         72.00M    1 def run_model():
#      469.49M        518.00M    2     model = initialize_model()
#      469.49M        518.00M    3     data, labels = get_data()
#      473.95M        522.00M    4     loss, logits = model(data.input_ids, token_type_ids=None, attention_mask=data.attention_mask, labels=labels)
#      469.49M        522.00M    5     return loss
#
#
# ## initialize_model
#
# active_bytes reserved_bytes line code
#          all            all
#         peak           peak
#       58.29M         72.00M    1 def initialize_model():
#      469.49M        518.00M    2     model = BertForTokenClassification.from_pretrained('bert-base-cased', num_labels=10).cuda()
#      469.49M        518.00M    3     return model
#
#
# ## get_data
#
# active_bytes reserved_bytes line code
#          all            all
#         peak           peak
#      469.49M        518.00M    1 def get_data():
#      469.49M        518.00M    2     device = torch.device('cuda:0')
#      469.49M        518.00M    3     tokenizer = BertTokenizerFast.from_pretrained('bert-base-cased')
#      469.49M        518.00M    4     data = tokenizer(['This is a sentence'], return_tensors='pt').to(device)
#      469.49M        518.00M    5     labels = torch.Tensor([1] * len(data.input_ids[0])).to(dtype=torch.long).cuda()
#      469.49M        518.00M    6     return data, labels

# %% [markdown]
# Not very much useful data. Let's try to look at the BERT forward function...

# %% [markdown]
# ### BERT forward function

# %%
# %reset -f

# %%
import torch
from pytorch_memlab import LineProfiler, MemReporter, profile
from transformers import BertForTokenClassification, BertTokenizerFast

class ProfiledBertForTokenClassification(BertForTokenClassification):
    def __init__(self, config):
        super().__init__(config)

    def forward(self, *args, **kwargs):
        with LineProfiler(super().forward) as prof:
            result = super().forward(*args, **kwargs)
        # jupyter display stops working here, so I had to print stats
        print(prof.display())
        return result

model = ProfiledBertForTokenClassification.from_pretrained('bert-base-cased', num_labels=10).cuda()
device = torch.device('cuda:0')
tokenizer = BertTokenizerFast.from_pretrained('bert-base-cased')
data = tokenizer(['This is a sentence'], return_tensors='pt').to(device)
labels = torch.Tensor([1] * len(data.input_ids[0])).to(dtype=torch.long).cuda()
loss, logits = model(data.input_ids, token_type_ids=None, attention_mask=data.attention_mask, labels=labels)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing ProfiledBertForTokenClassification: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing ProfiledBertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ProfiledBertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ProfiledBertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ## BertForTokenClassification.forward
#
# active_bytes reserved_bytes line code
#          all            all
#         peak           peak
#      469.49M        518.00M 1731     @add_start_docstrings_to_model_forward(BERT_INPUTS_DOCSTRING.format("batch_size, sequence_length"))
#                             1732     @add_code_sample_docstrings(
#                             1733         checkpoint=_CHECKPOINT_FOR_TOKEN_CLASSIFICATION,
#                             1734         output_type=TokenClassifierOutput,
#                             1735         config_class=_CONFIG_FOR_DOC,
#                             1736         expected_output=_TOKEN_CLASS_EXPECTED_OUTPUT,
#                             1737         expected_loss=_TOKEN_CLASS_EXPECTED_LOSS,
#                             1738     )
#                             1739     def forward(
#                             1740         self,
#                             1741         input_ids: Optional[torch.Tensor] = None,
#                             1742         attention_mask: Optional[torch.Tensor] = None,
#                             1743         token_type_ids: Optional[torch.Tensor] = None,
#                             1744         position_ids: Optional[torch.Tensor] = None,
#                             1745         head_mask: Optional[torch.Tensor] = None,
#                             1746         inputs_embeds: Optional[torch.Tensor] = None,
#                             1747         labels: Optional[torch.Tensor] = None,
#                             1748         output_attentions: Optional[bool] = None,
#                             1749         output_hidden_states: Optional[bool] = None,
#                             1750         return_dict: Optional[bool] = None,
#                             1751     ) -> Union[Tuple[torch.Tensor], TokenClassifierOutput]:
#                             1752         r"""
#                             1753         labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#                             1754             Labels for computing the token classification loss. Indices should be in `[0, ..., config.num_labels - 1]`.
#                             1755         """
#      469.49M        518.00M 1756         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#                             1757
#      473.93M        522.00M 1758         outputs = self.bert(
#      469.49M        518.00M 1759             input_ids,
#      469.49M        518.00M 1760             attention_mask=attention_mask,
#      469.49M        518.00M 1761             token_type_ids=token_type_ids,
#      469.49M        518.00M 1762             position_ids=position_ids,
#      469.49M        518.00M 1763             head_mask=head_mask,
#      469.49M        518.00M 1764             inputs_embeds=inputs_embeds,
#      469.49M        518.00M 1765             output_attentions=output_attentions,
#      469.49M        518.00M 1766             output_hidden_states=output_hidden_states,
#      469.49M        518.00M 1767             return_dict=return_dict,
#                             1768         )
#                             1769
#      472.95M        522.00M 1770         sequence_output = outputs[0]
#                             1771
#      472.95M        522.00M 1772         sequence_output = self.dropout(sequence_output)
#      473.95M        522.00M 1773         logits = self.classifier(sequence_output)
#                             1774
#      472.95M        522.00M 1775         loss = None
#      472.95M        522.00M 1776         if labels is not None:
#      472.95M        522.00M 1777             loss_fct = CrossEntropyLoss()
#      472.95M        522.00M 1778             loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))
#                             1779
#      472.95M        522.00M 1780         if not return_dict:
#                             1781             output = (logits,) + outputs[2:]
#                             1782             return ((loss,) + output) if loss is not None else output
#                             1783
#      472.95M        522.00M 1784         return TokenClassifierOutput(
#      472.95M        522.00M 1785             loss=loss,
#      472.95M        522.00M 1786             logits=logits,
#      472.95M        522.00M 1787             hidden_states=outputs.hidden_states,
#      472.95M        522.00M 1788             attentions=outputs.attentions,
#                             1789         )
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:60: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   records = (_accumulate_line_records(raw_line_records)
# /usr/local/lib/python3.9/dist-packages/pytorch_memlab/line_profiler/line_records.py:189: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   merged = merged.drop('code', 1, level=0)

# %%
# !pip install torch_tb_profiler
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch_tb_profiler
#   Downloading torch_tb_profiler-0.4.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in /usr/local/lib/python3.9/dist-packages (from torch_tb_profiler) (2.11.2)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from torch_tb_profiler) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->torch_tb_profiler) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->torch_tb_profiler) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->torch_tb_profiler) (1.22.4)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (3.19.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (0.6.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (1.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (2.27.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (0.40.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (2.16.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (2.2.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (67.6.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (1.51.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (6.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.1.0,>=1.15->torch_tb_profiler) (3.2.2)
# Installing collected packages: torch_tb_profiler
# Successfully installed torch_tb_profiler-0.4.1

# %%
from torch.profiler import tensorboard_trace_handler

# %%
 with torch.profiler.profile(
    schedule=torch.profiler.schedule(
        wait=2,
        warmup=2,
        active=6,
        repeat=1),
    on_trace_ready=tensorboard_trace_handler,
    with_stack=True) as profiler:
    for step, data in enumerate(trainloader, 0):
        print("step:{}".format(step))
        inputs, labels = data[0].to(device=device), data[1].to(device=device)

        outputs = model(inputs)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        profiler.step()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-aecd7670be68> in <module>
#       7    on_trace_ready=tensorboard_trace_handler,
#       8    with_stack=True) as profiler:
# ----> 9    for step, data in enumerate(trainloader, 0):
#      10        print("step:{}".format(step))
#      11        inputs, labels = data[0].to(device=device), data[1].to(device=device)
#
# NameError: name 'trainloader' is not defined

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 24.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.4.4)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.13.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 25.5 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 31.3 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.10.1 dill-0.3.6 frozenlist-1.3.3 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.8.2

# %%
from datasets import load_dataset, load_metric
from transformers import AutoTokenizer, DataCollatorWithPadding, AutoModelForSequenceClassification
from transformers import Trainer, TrainingArguments, TrainerCallback
import torch
import numpy as np
import time


raw_datasets = load_dataset("glue", "mrpc")
checkpoint = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)

def tokenize_function(example):
    return tokenizer(example["sentence1"], example["sentence2"], truncation=True)

tokenized_datasets = raw_datasets.map(tokenize_function, batched=True)
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

model = AutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=2)

def compute_metrics(eval_preds):
    metric = load_metric("glue", "mrpc")
    logits, labels = eval_preds
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

training_args = TrainingArguments("test-trainer", evaluation_strategy="epoch", num_train_epochs=1, fp16=True)
model = AutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=2)

trainer = Trainer(
    model,
    training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

start = time.perf_counter()

class ProfCallback(TrainerCallback):
    def __init__(self, prof):
        self.prof = prof

    def on_step_end(self, args, state, control, **kwargs):
        self.prof.step()

with torch.profiler.profile(activities=[torch.profiler.ProfilerActivity.CPU,
                                        torch.profiler.ProfilerActivity.CUDA], 
                            schedule=torch.profiler.schedule(skip_first=3, wait=1, warmup=1, active=2, repeat=2),
                            on_trace_ready=torch.profiler.tensorboard_trace_handler('hf-training-trainer'),
                            profile_memory=True,
                            with_stack=True,
                            record_shapes=True) as prof:
    
    trainer.add_callback(ProfCallback(prof=prof))
    trainer.train()

print(f'training time, {(time.perf_counter() - start):.1f} s')
# Out:
# Downloading builder script:   0%|          | 0.00/28.8k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/28.7k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/27.9k [00:00<?, ?B/s]
# Downloading and preparing dataset glue/mrpc to /root/.cache/huggingface/datasets/glue/mrpc/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data: 0.00B [00:00, ?B/s]
# Downloading data: 0.00B [00:00, ?B/s]
# Downloading data: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/3668 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/408 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1725 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/mrpc/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Map:   0%|          | 0/3668 [00:00<?, ? examples/s]
# Map:   0%|          | 0/408 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1725 [00:00<?, ? examples/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='459' max='459' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [459/459 01:11, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.424045</td>
#       <td>0.803922</td>
#       <td>0.861592</td>
#     </tr>
#   </tbody>
# </table><p>
# <ipython-input-45-d61162a5ae92>:22: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("glue", "mrpc")
# Downloading builder script:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# training time, 71.5 s
